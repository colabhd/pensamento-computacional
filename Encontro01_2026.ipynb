# %% [markdown]
# <a href="https://colab.research.google.com/github/colabhd/pensamento-computacional/blob/main/Encontro01_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Pensamento Computacional

# %% [markdown]
# ## Noções Gerais

# %% [markdown]
# ## Fundamentos Programação
